# %% [markdown]
# 1. install pymysql
#
# done

# %% [markdown]
# 2. add env to .gitignore
#
# done

# %% [markdown]
# 3. Create a function named get_db_url. It should accept a
# username, hostname, password, and database name and return
# a url connection string formatted like in the example at the start of this lesson.

# %%
from env import host, user, password

# %%
import pandas as pd
import numpy as np

# %%
def get_db_url(db_name, host=host, user=user, password=password):
    url = f'mysql+pymysql://{user}:{password}@{host}/{db_name}'
    return url

# %% [markdown]
# 4. Use your function to obtain a connection to the employees database.

# %%
connection = get_db_url('employees')

# %% [markdown]
# 5. Once you have successfully run a query:

# %%
pd.read_sql('''
SELECT *
FROM employees
LIMIT 5;
''', connection)
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %% [markdown]
# a. Intentionally make a typo in the database url. What kind of error message do you see?

# %%
bad_connection = get_db_url('employ')

pd.read_sql('''
SELECT *
FROM employees
LIMIT 5;
''', bad_connection)

# %% [markdown]
# # What kind of error message do you see?
# OperationalError: (pymysql.err.OperationalError) (
#     1044, "Access denied for user xxxx@'%' to database 'employ'")
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# b. Intentionally make an error in your SQL query. What does the error message look like?

# %%
pd.read_sql('''
SELECT *
FROM employ
LIMIT 5;
''', connection)

# %% [markdown]
# # What does the error message look like?
# ProgrammingError: (pymysql.err.ProgrammingError) (1146, "Table 'employees.employ' doesn't exist")
# [SQL:
# SELECT *
# FROM employ
# LIMIT 5;
# ]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# 6. Read the employees and titles tables into two separate DataFrames.

# %%
employees_query = '''
SELECT *
FROM employees;
'''

employees_df = pd.read_sql(employees_query, connection)
employees_df.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
titles_query = '''
SELECT *
FROM titles;
'''

titles_df = pd.read_sql(titles_query, connection)
titles_df.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %% [markdown]
# 7. How many rows and columns do you have in each DataFrame? Is that what you expected?

# %%
employees_df.shape
# 300,024 rows, 6 columns
# expected 300,024 rows, 6 columns
# Out:
# (300024, 6)

# %%
titles_df.shape
# 443,308 rows, 4 columns
# expected 443,308 rows, 4 columns
# Out:
# (443308, 4)

# %% [markdown]
# 8. Display the summary statistics for each DataFrame.

# %%
employees_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300024 entries, 0 to 300023
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      300024 non-null  int64
#  1   birth_date  300024 non-null  object
#  2   first_name  300024 non-null  object
#  3   last_name   300024 non-null  object
#  4   gender      300024 non-null  object
#  5   hire_date   300024 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 13.7+ MB

# %%
employees_df[['birth_date', 'first_name', 'last_name', 'gender', 'hire_date']].describe()
# Out:
#         birth_date first_name last_name  gender   hire_date
# count       300024     300024    300024  300024      300024
# unique        4750       1275      1637       2        5434
# top     1952-03-08     Shahab      Baba       M  1985-06-20
# freq            95        295       226  179973         132

# %%
titles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443308 entries, 0 to 443307
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   emp_no     443308 non-null  int64
#  1   title      443308 non-null  object
#  2   from_date  443308 non-null  object
#  3   to_date    443308 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 13.5+ MB

# %%
titles_df[['title', 'from_date', 'to_date']].describe()
# Out:
#            title   from_date     to_date
# count     443308      443308      443308
# unique         7        6393        5888
# top     Engineer  1998-10-25  9999-01-01
# freq      115003         132      240124

# %% [markdown]
# 9. How many unique titles are in the titles DataFrame?

# %%
len(titles_df.title.unique())
# Out:
# 7

# %%
titles_df.title.nunique()
# Out:
# 7

# %% [markdown]
# 10. What is the oldest date in the to_date column?

# %%
min(titles_df.to_date)
# Out:
# datetime.date(1985, 3, 1)

# %% [markdown]
# 11. What is the most recent date in the to_date column?

# %%
import datetime

# %%
max(titles_df.to_date[titles_df.to_date < datetime.date.today()])
# Out:
# datetime.date(2002, 8, 1)

# %%
max(titles_df.to_date[titles_df.to_date < max(titles_df.to_date)])
# Out:
# datetime.date(2002, 8, 1)

# %% [markdown]
# # Exercises part 2

# %% [markdown]
# 1. Copy the users and roles DataFrames from the examples above.

# %%
# Create the users DataFrame.
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
# Create the roles DataFrame
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# 2. What is the result of using a right join on the DataFrames?

# %%
pd.merge(users, roles, how='right', left_on='role_id', right_on='id')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0     1      admin
# 1   2.0    joe      2.0     2     author
# 2   3.0  sally      3.0     3   reviewer
# 3   4.0   adam      3.0     3   reviewer
# 4   NaN    NaN      NaN     4  commenter

# %% [markdown]
# 3. What is the result of using an outer join on the DataFrames?

# %%
pd.merge(users, roles, how='outer', left_on='role_id', right_on='id')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0   1.0      admin
# 1   2.0    joe      2.0   2.0     author
# 2   3.0  sally      3.0   3.0   reviewer
# 3   4.0   adam      3.0   3.0   reviewer
# 4   5.0   jane      NaN   NaN        NaN
# 5   6.0   mike      NaN   NaN        NaN
# 6   NaN    NaN      NaN   4.0  commenter

# %% [markdown]
# 4. What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
users_temp = users.drop(columns='role_id')

# %%
pd.merge(users_temp, roles, how='outer', on='id')
# Out:
#    id name_x     name_y
# 0   1    bob      admin
# 1   2    joe     author
# 2   3  sally   reviewer
# 3   4   adam  commenter
# 4   5   jane        NaN
# 5   6   mike        NaN

# %% [markdown]
# we can still merge using 'id', but the info is incorrect since it's just listing the info from each table as if it was concatonated together.

# %% [markdown]
# 5. Load the mpg dataset from PyDataset.

# %%
from pydataset import data

# %%
mpg = data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %% [markdown]
# 6. Output and read the documentation for the mpg dataset.

# %%
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# 7. How many rows and columns are in the dataset?

# %%
mpg.shape
#234 rows, 11 columns
# Out:
# (234, 11)

# %% [markdown]
# 8. Check out your column names and perform any cleanup you may want on them.

# %%
mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %%
mpg = mpg.rename(columns= {'cty':'city', 'fl':'fuel', 'class':'cls'})
#class is a reserved word, so we want to change that column name to something else
mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'city',
#        'hwy', 'fuel', 'cls', 'mileage_difference', 'average_mileage',
#        'is_automatic'],
#       dtype='object')

# %% [markdown]
# 9. Display the summary statistics for the dataset.

# %%
mpg.describe().round(1)
# Out:
#        displ    year    cyl   city    hwy
# count  234.0   234.0  234.0  234.0  234.0
# mean     3.5  2003.5    5.9   16.9   23.4
# std      1.3     4.5    1.6    4.3    6.0
# min      1.6  1999.0    4.0    9.0   12.0
# 25%      2.4  1999.0    4.0   14.0   18.0
# 50%      3.3  2003.5    6.0   17.0   24.0
# 75%      4.6  2008.0    8.0   19.0   27.0
# max      7.0  2008.0    8.0   35.0   44.0

# %% [markdown]
# 10. How many different manufacturers are there?

# %%
mpg.manufacturer.nunique()
# Out:
# 15

# %% [markdown]
# 11. How many different models are there?

# %%
mpg.model.nunique()
# Out:
# 38

# %% [markdown]
# 12. Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = mpg.hwy - mpg.city
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#        class  mileage_difference
# 1    compact                  11
# ...

# %% [markdown]
# 13. Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg.hwy + mpg.city) / 2
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#        class  mileage_difference  average_mileage
# ...

# %%
mpg[['city','hwy']].agg('mean', axis=1)
# Out:
# 1      23.5
# 2      25.0
# 3      25.5
# 4      25.5
# 5      21.0
#        ...
# 230    23.5
# 231    25.0
# 232    21.0
# 233    22.0
# 234    21.5
# Length: 234, dtype: float64

# %%
mpg[['city','hwy']].mean(axis=1)
# Out:
# 1      23.5
# 2      25.0
# 3      25.5
# 4      25.5
# 5      21.0
#        ...
# 230    23.5
# 231    25.0
# 232    21.0
# 233    22.0
# 234    21.5
# Length: 234, dtype: float64

# %% [markdown]
# 14. Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
mpg['is_automatic'] = mpg.trans.str.contains('auto')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#        class  mileage_difference  average_mileage  is_automatic
# ...

# %%
mpg.trans.str.startswith('auto')
# Out:
# 1       True
# 2      False
# 3      False
# 4       True
# 5       True
#        ...
# 230     True
# 231    False
# 232     True
# 233    False
# 234     True
# Name: trans, Length: 234, dtype: bool

# %%
mpg.trans.apply(lambda x: 'auto' in x)
# Out:
# 1       True
# 2      False
# 3      False
# 4       True
# 5       True
#        ...
# 230     True
# 231    False
# 232     True
# 233    False
# 234     True
# Name: trans, Length: 234, dtype: bool

# %% [markdown]
# 15. Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
mpg.groupby(['manufacturer'])[['average_mileage']].agg('mean').sort_values(
    'average_mileage', ascending=False).head(1)
#honda
# Out:
#               average_mileage
# manufacturer
# honda                    28.5

# %%
mpg.groupby('manufacturer').average_mileage.mean().nlargest(1, keep='all')
# Out:
# manufacturer
# honda    28.5
# Name: average_mileage, dtype: float64

# %% [markdown]
# 16. Do automatic or manual cars have better miles per gallon?

# %%
mpg.groupby(['is_automatic'])[['average_mileage']].agg('mean').round(1) 
#manuals have better mpg on average
# Out:
#               average_mileage
# is_automatic
# False                    22.2
# True                     19.1

# %%
mpg.groupby('is_automatic').average_mileage.mean().round(1)
# Out:
# is_automatic
# False    22.2
# True     19.1
# Name: average_mileage, dtype: float64

# %% [markdown]
# # Exercise 3

# %% [markdown]
# 1. Use your get_db_url function to help you explore the data from the chipotle database.

# %%
connection = get_db_url('chipotle')

# %%
query = 'SELECT * FROM orders'

df = pd.read_sql(query, connection)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  4622 non-null   object
#  5   item_price          4622 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 216.8+ KB

# %%
df.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                nan     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                nan     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.shape
# Out:
# (4622, 6)

# %% [markdown]
# 2. What is the total price for each order?

# %%
df['item_total'] = df.item_price.str.replace(
    '$','', regex=False).astype(float)

# %%
df.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                   choice_description item_price  item_total
# 0                                                nan     $2.39         2.39
# 1                                       [Clementine]     $3.39         3.39
# 2                                            [Apple]     $3.39         3.39
# 3                                                nan     $2.39         2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98        16.98

# %%
df['order_id'].nunique()
# Out:
# 1834

# %%
#What is the total price for each order?
df[['order_id','item_total']].groupby('order_id').sum()
# Out:
#           item_total
# order_id
# 1              11.56
# 2              16.98
# 3              12.67
# 4              21.00
# 5              13.70
# ...              ...
# 1830           23.00
# 1831           12.90
# 1832           13.20
# 1833           23.50
# 1834           28.75
#
# [1834 rows x 1 columns]

# %%
df.groupby('order_id').item_total.sum()
# Out:
# order_id
# 1       11.56
# 2       16.98
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: item_total, Length: 1834, dtype: float64

# %% [markdown]
# 3. What are the most popular 3 items?

# %%
df.groupby('item_name').quantity.sum().nlargest(3,'all')
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Name: quantity, dtype: int64

# %% [markdown]
# 4. Which item has produced the most revenue?

# %%
df.groupby('item_name').item_total.sum().nlargest(1)
# Out:
# item_name
# Chicken Bowl    7342.73
# Name: item_total, dtype: float64

# %% [markdown]
# 5. Join the employees and titles DataFrames together.

# %%
employees_df.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
titles_df.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %%
emp_df = pd.merge(employees_df, titles_df, how='inner', on='emp_no')
emp_df
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# ...

# %% [markdown]
# 6. For each title, find the hire date of the employee that was hired most recently with that title.

# %%
emp_df.groupby('title').hire_date.max()
# Out:
# title
# Assistant Engineer    1999-12-24
# Engineer              2000-01-28
# Manager               1992-02-05
# Senior Engineer       2000-01-01
# Senior Staff          2000-01-13
# Staff                 2000-01-12
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %%
emp_df.pivot_table(index='title', values='hire_date', aggfunc='max')
# Out:
#                      hire_date
# title
# Assistant Engineer  1999-12-24
# Engineer            2000-01-28
# Manager             1992-02-05
# Senior Engineer     2000-01-01
# Senior Staff        2000-01-13
# Staff               2000-01-12
# Technique Leader    1999-12-31

# %%
# 7. Write the code necessary to 
# create a cross tabulation of the number of titles by department. 
# (Hint: this will involve a combination of SQL code to pull the 
# necessary data and python/pandas code to perform the manipulations.)
connection = get_db_url('employees')
query = '''
SELECT emp_no, title, dept_name 
FROM titles
	JOIN dept_emp
		USING (emp_no)
	JOIN departments
		USING (dept_no)
;'''

df = pd.read_sql(query, connection)

# %%
df.head()
# Out:
#    emp_no         title         dept_name
# 0   10011         Staff  Customer Service
# 1   10038  Senior Staff  Customer Service
# 2   10038         Staff  Customer Service
# 3   10049  Senior Staff  Customer Service
# 4   10049         Staff  Customer Service

# %%
df.shape
# Out:
# (489903, 3)

# %%
pd.crosstab(df.dept_name, df.title)
# Out:
# title               Assistant Engineer  Engineer  Manager  Senior Engineer  \
# dept_name
# Customer Service                   298      2362        4             2027
# Development                       7769     58135        2            49326
# Finance                              0         0        2                0
# Human Resources                      0         0        2                0
# Marketing                            0         0        2                0
# Production                        6445     49649        4            42205
# Quality Management                1831     13852        4            11864
# Research                           378      2986        2             2570
# Sales                                0         0        2                0
#
# title               Senior Staff  Staff  Technique Leader
# dept_name
# Customer Service           13925  16150               309
# Development                 1247   1424              7683
# ...

# %%
pd.crosstab(df.dept_name, df.title, margins=True)
# Out:
# title               Assistant Engineer  Engineer  Manager  Senior Engineer  \
# dept_name
# Customer Service                   298      2362        4             2027
# Development                       7769     58135        2            49326
# Finance                              0         0        2                0
# Human Resources                      0         0        2                0
# Marketing                            0         0        2                0
# Production                        6445     49649        4            42205
# Quality Management                1831     13852        4            11864
# Research                           378      2986        2             2570
# Sales                                0         0        2                0
# All                              16721    126984       24           107992
#
# title               Senior Staff   Staff  Technique Leader     All
# dept_name
# ...

# %%
pd.crosstab(df.dept_name, df.title, normalize=True, margins=True).round(6) * 100
# Out:
# title               Assistant Engineer  Engineer  Manager  Senior Engineer  \
# dept_name
# Customer Service                0.0608    0.4821   0.0008           0.4138
# Development                     1.5858   11.8666   0.0004          10.0685
# Finance                         0.0000    0.0000   0.0004           0.0000
# Human Resources                 0.0000    0.0000   0.0004           0.0000
# Marketing                       0.0000    0.0000   0.0004           0.0000
# Production                      1.3156   10.1345   0.0008           8.6150
# Quality Management              0.3737    2.8275   0.0008           2.4217
# Research                        0.0772    0.6095   0.0004           0.5246
# Sales                           0.0000    0.0000   0.0004           0.0000
# All                             3.4131   25.9202   0.0049          22.0435
#
# title               Senior Staff    Staff  Technique Leader       All
# dept_name
# ...

# %% [markdown]
# # Extra
# crosstab for CURRENT titles and departments

# %%
query = '''
SELECT emp_no, title, dept_name 
FROM titles
	JOIN dept_emp
		USING (emp_no)
	JOIN departments
		USING (dept_no)
WHERE titles.to_date > now()
	AND dept_emp.to_date > now()
;'''

ext_df = pd.read_sql(query, connection)

# %%
ext_df.shape
# Out:
# (240124, 3)

# %%
pd.crosstab(ext_df.dept_name, ext_df.title, normalize=True, margins=True).round(6) * 100
# Out:
# title               Assistant Engineer  Engineer  Manager  Senior Engineer  \
# dept_name
# Customer Service                0.0283    0.2611   0.0004           0.7454
# Development                     0.6880    5.8470   0.0004          16.1650
# Finance                         0.0000    0.0000   0.0004           0.0000
# Human Resources                 0.0000    0.0000   0.0004           0.0000
# Marketing                       0.0000    0.0000   0.0004           0.0000
# Production                      0.5839    5.0312   0.0004          14.0032
# Quality Management              0.1620    1.4180   0.0004           3.9388
# Research                        0.0321    0.3457   0.0004           0.9370
# Sales                           0.0000    0.0000   0.0004           0.0000
# All                             1.4942   12.9029   0.0037          35.7894
#
# title               Senior Staff    Staff  Technique Leader       All
# dept_name
# ...

# %% [markdown]
# What is the salary distribution for title and department among current employees?

# %%
query = '''
SELECT emp_no, title, dept_name, salary
FROM titles
	JOIN dept_emp
		USING (emp_no)
	JOIN departments
		USING (dept_no)
	JOIN salaries
		USING (emp_no)
WHERE titles.to_date > now()
	AND dept_emp.to_date > now()
    AND salaries.to_date > now()
;'''

extra_df = pd.read_sql(query, connection)

# %%
extra_df.head()
# Out:
#    emp_no         title         dept_name  salary
# 0   10038  Senior Staff  Customer Service   64254
# 1   10049  Senior Staff  Customer Service   51326
# 2   10060  Senior Staff  Customer Service   93188
# 3   10088  Senior Staff  Customer Service   98003
# 4   10112         Staff  Customer Service   61070

# %%
extra_df.shape
# Out:
# (240124, 4)

# %%
pd.pivot_table(data=extra_df, values='salary', index='dept_name', 
               columns='title', aggfunc='sum', margins=True)
# Out:
# title               Assistant Engineer      Engineer   Manager  \
# dept_name
# Customer Service             4013699.0  3.735998e+07   58745.0
# Development                 95209078.0  8.389918e+08   74510.0
# Finance                            NaN           NaN   83457.0
# Human Resources                    NaN           NaN   65400.0
# Marketing                          NaN           NaN  106491.0
# Production                  80311082.0  7.249665e+08   56654.0
# Quality Management          21607713.0  1.952076e+08   72876.0
# Research                     4513882.0  5.014574e+07   79393.0
# Sales                              NaN           NaN  101987.0
# All                        205655454.0  1.846672e+09  699513.0
#
# title               Senior Engineer  Senior Staff         Staff  \
# dept_name
# Customer Service       1.274902e+08  7.919296e+08  2.051514e+08
# Development            2.754763e+09  7.435305e+07  1.760167e+07
# ...

# %%
pd.crosstab(values=extra_df['salary'], index=extra_df['dept_name'], 
            columns=extra_df['title'], aggfunc='sum', 
            margins=True, normalize=True).round(6) * 100
# Out:
# title               Assistant Engineer  Engineer  Manager  Senior Engineer  \
# dept_name
# Customer Service                0.0232    0.2161   0.0003           0.7373
# Development                     0.5506    4.8519   0.0004          15.9310
# Finance                         0.0000    0.0000   0.0005           0.0000
# Human Resources                 0.0000    0.0000   0.0004           0.0000
# Marketing                       0.0000    0.0000   0.0006           0.0000
# Production                      0.4644    4.1925   0.0003          13.8470
# Quality Management              0.1250    1.1289   0.0004           3.7639
# Research                        0.0261    0.2900   0.0005           0.9195
# Sales                           0.0000    0.0000   0.0006           0.0000
# All                             1.1893   10.6794   0.0040          35.1986
#
# title               Senior Staff   Staff  Technique Leader       All
# dept_name
# ...
